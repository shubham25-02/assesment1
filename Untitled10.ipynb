# %% [markdown]
# number:-it is a datatype which stores numeric value.
# strings:-it is a derived data type which has a sequence of characters
# list:-list is a collection of elements separated by commas and enclosed in braces
# tuple:-tuple is a collection of elements which is ordered and unchangeable
# dictionary:- it is a collection of key value pairs

# %%
(150-50)+(2**2+(2/2)-5+(1/4))
# Out:
# 100.25

# %%
4*(6+5)
# Out:
# 44

# %%
4*6+5
# Out:
# 29

# %%
4+6*5
# Out:
# 34

# %%
check_mytype = 3 + 1.5 + 4
# Out:
# 8.5

# %%
type(check_mytype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-20f78bb89852> in <module>
# ----> 1 type(check_mytype)
#
# NameError: name 'check_mytype' is not defined

# %%
check_type = 3 + 1.5 + 4

# %%
type(check_type)
# Out:
# float

# %%
10000**0.5
# Out:
# 100.0

# %%
34**2
# Out:
# 1156

# %%
s='hello'

# %%
s[1]
# Out:
# 'e'

# %%
s[::-1]
# Out:
# 'olleh'

# %%
s[4]
# Out:
# 'o'

# %%
s[-1]
# Out:
# 'o'

# %%
list=[0,0,0]

# %%
[0]*3
# Out:
# [0, 0, 0]

# %%
list
# Out:
# [0, 0, 0]

# %%
list3 = [1,2,[3,4,'hello']]

# %%
list3[2][2]='goodbye'

# %%
list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %%
list3[2][1]='hey'

# %%
list3
# Out:
# [1, 2, [3, 'hey', 'goodbye']]

# %%
list4 = [5,3,4,6,1]

# %%
list4.sort()

# %%
list4
# Out:
# [1, 3, 4, 5, 6]

# %%
d = {'simple_key':'hello'}

# %%
d['simple_key']
# Out:
# 'hello'

# %%
d = {'k1':{'k2':'hello'}}

d['k1']['k2']
# Out:
# 'hello'

# %%
list5 = [1,2,2,33,4,4,11,22,3,3,2]

# %%
set(list5)
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %%
2>4
# Out:
# False

# %%
3 <= 2
# Out:
# False

# %%
3 == 2.0
# Out:
# False

# %%
3.0 == 3
# Out:
# True

# %%
4**0.5 != 2
# Out:
# False

# %%
l_one = [1,2,[3,4]]
l_two = [1,2,{'k1':4}]

l_one[2][0] >= l_two[2]['k1']
# Out:
# False
